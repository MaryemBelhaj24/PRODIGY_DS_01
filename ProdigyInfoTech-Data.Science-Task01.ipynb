# %% [markdown]
# <span style="font-size: 25px;">**Task-01**</span>

# %% [markdown]
# <span style="font-size: 14px;">**Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population**</span>

# %% [markdown]
# <span style="font-size: 14px;">**Sample Dataset :- https://data.worldbank.org/indicator/SP.POP.TOTL**</span>

# %%
#Importing libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Reading Dataset
df=pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_426474.csv", skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
#Columns
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
# Remove columns with all NaN values
df = df.dropna(axis=1, how='all')

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
#Data types of each column
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Length: 67, dtype: object

# %%
#Shape
df.shape
# Out:
# (266, 67)

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# ...

# %%
#Information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
#Checking the count of null values 
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
# Use interpolate to fill missing values in numerical columns
df=df.interpolate()

# %%
#rechecking
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# Length: 67, dtype: int64

# %%
#Columns name change
df.columns=[each.split()[0] if(len(each.split())>2) else each.replace(" ","_") for each in df.columns]
df.head()
# Out:
#                   Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
#Unique values in the 'Country_Name' column
df.Country_Name.unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
#filter data
df2=df[['Country_Name', '2022']].iloc[:10]
df2
# Out:
#                   Country_Name         2022
# 0                        Aruba     106445.0
# 1  Africa Eastern and Southern  720859132.0
# 2                  Afghanistan   41128771.0
# 3   Africa Western and Central  490330870.0
# 4                       Angola   35588987.0
# 5                      Albania    2777689.0
# 6                      Andorra      79824.0
# 7                   Arab World  464684914.0
# 8         United Arab Emirates    9441129.0
# 9                    Argentina   46234830.0

# %%
plt.figure(figsize=(9,5))
sns.barplot(x=df2['Country_Name'], y=df2['2022'], palette="magma")
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Total Population by Country in 2022')
plt.yscale('log')  # Set the scale of the y-axis to be logarithmic
plt.xticks(rotation=90)
plt.show()

# %%
# Sort the DataFrame based on the population in 2022 in descending order
df_sorted = df.sort_values(by='2022', ascending=False)

# %%
# Select the top 10 countries
df_top10 = df_sorted.head(10)

# %%
# Create the bar plot
plt.figure(figsize=(9,5))
sns.barplot(x=df_top10['Country_Name'], y=df_top10['2022'], palette="rocket")
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Top 10 Countries by Population in 2022')
plt.yscale('log')  # Set the scale of the y-axis to be logarithmic
plt.xticks(rotation=90)
plt.show()

# %%
# Sort the DataFrame based on the population in 2022 in ascending order
df_sorted = df.sort_values(by='2022', ascending=True)

# Select the bottom 10 countries
df_bottom10 = df_sorted.head(10)

# Create the bar plot
plt.figure(figsize=(9,5))
sns.barplot(x=df_bottom10['Country_Name'], y=df_bottom10['2022'], palette="binary")
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Bottom 10 Countries by Population in 2022')
plt.yscale('log')  # Set the scale of the y-axis to be logarithmic
plt.xticks(rotation=90)
plt.show()

# %%
#Reading Dataset 2
df3=pd.read_csv("Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_426474.csv")
df3
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df3=df3.fillna("not classified")
df3
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE              not classified       not classified
# 2            AFG                  South Asia           Low income
# 3            AFW              not classified       not classified
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                       not classified
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df3.columns=[each.split()[0] if(len(each.split())>2) else each.replace(" ","_") for each in df3.columns]
# Merge the two DataFrames on the 'country code' column
merged_df = pd.merge(df, df3, on='Country_Code')
merged_df
# Out:
#                     Country_Name Country_Code     Indicator_Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 260                       Kosovo          XKX  Population, total
# 261                  Yemen, Rep.          YEM  Population, total
# 262                 South Africa          ZAF  Population, total
# 263                       Zambia          ZMB  Population, total
# 264                     Zimbabwe          ZWE  Population, total
#
#     Indicator_Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
#Creating a 2x2 subplot grid
f, axs = plt.subplots(2, 2, figsize=(10, 10), constrained_layout=True)
# Filter data for each income group
high_income_df = merged_df[merged_df['IncomeGroup'] == 'High income']
low_income_df = merged_df[merged_df['IncomeGroup'] == 'Low income']
upper_middle_income_df = merged_df[merged_df['IncomeGroup'] == 'Upper middle income']
lower_middle_income_df = merged_df[merged_df['IncomeGroup'] == 'Lower middle income']

# Sort and select top 10 countries for each income group
sort_high = high_income_df.sort_values(by=['2022', '2021', '2020'], ascending=False).head(10)
sort_low = low_income_df.sort_values(by=['2022', '2021', '2020'], ascending=False).head(10)
sort_upper_middle = upper_middle_income_df.sort_values(by=['2022', '2021', '2020'], ascending=False).head(10)
sort_lower_middle = lower_middle_income_df.sort_values(by=['2022', '2021', '2020'], ascending=False).head(10)

# Reshape the data to "long" format
sort_high_long = pd.melt(sort_high, id_vars='Country_Name', value_vars=['2022', '2021', '2020'], var_name='Year', value_name='High income')
sort_low_long=pd.melt(sort_low,id_vars='Country_Name',value_vars=['2022', '2021', '2020'], var_name='Year', value_name='low income')
sort_upper_middle_long=pd.melt(sort_upper_middle,id_vars='Country_Name',value_vars=['2022', '2021', '2020'], var_name='Year', value_name='upper middle income')
sort_lower_middle_long=pd.melt(sort_lower_middle,id_vars='Country_Name',value_vars=['2022', '2021', '2020'], var_name='Year', value_name='lower middle income')

# Create the bar plot 
ax = sns.barplot(x="Country_Name", y="High income", hue="Year", data=sort_high_long, ax=axs[0, 0], palette="viridis")
ax.set_yscale("log")
ax.tick_params(axis='x', rotation=45)
ax.set_title('Top 10 High Income Countries Over Years')

ax = sns.barplot(x="Country_Name", y="low income", hue="Year", data=sort_low_long, ax=axs[0, 1], palette="viridis")
ax.set_yscale("log")
ax.tick_params(axis='x', rotation=45)
ax.set_title('Top 10 low Income Countries Over Years')


ax = sns.barplot(x="Country_Name", y="upper middle income", hue="Year", data=sort_upper_middle_long, ax=axs[1, 0], palette="viridis")
ax.set_yscale("log")
ax.tick_params(axis='x', rotation=45)
ax.set_title('Top 10 upper middle Income Countries Over Years')


ax = sns.barplot(x="Country_Name", y="lower middle income", hue="Year", data=sort_lower_middle_long, ax=axs[1, 1], palette="viridis")
ax.set_yscale("log")
ax.tick_params(axis='x', rotation=45)
ax.set_title('Top 10 lower middle Income Countries Over Years')

#Displaying the subplots
plt.show()
